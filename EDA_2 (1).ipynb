# %% [markdown]
# ## **EDA **

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 300
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/data_clean1.csv")

# %%
df
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
df.tail()
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C

# %%
df.describe(include=object)
# Out:
#        Month Weather
# count    158     155
# unique     6       3
# top        9       S
# freq      34      59

# %%
df.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    158 non-null    object
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 10.0+ KB

# %% [markdown]
# ## **data type conversion**

# %%
df['Month']
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 153    5
# 154    9
# 155    9
# 156    9
# 157    9
# Name: Month, Length: 158, dtype: object

# %%
df['Month'].unique()
# Out:
# array(['5', 'May', '6', '7', '8', '9'], dtype=object)

# %%
df['Month'].value_counts()
# Out:
# Month
# 9      34
# 5      31
# 7      31
# 8      31
# 6      30
# May     1
# Name: count, dtype: int64

# %%
df['Month'].replace("May","5",inplace =True)   # inplace used because of permanent change

# %%
df
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
df['Month'].unique()
# Out:
# array(['5', '6', '7', '8', '9'], dtype=object)

# %%
df.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
df['Month'].astype(int)   #no permanent change inplace is not allowed here
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 153    5
# 154    9
# 155    9
# 156    9
# 157    9
# Name: Month, Length: 158, dtype: int64

# %%
df.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
df['Month']=df['Month'].astype(int)
df['Month']
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 153    5
# 154    9
# 155    9
# 156    9
# 157    9
# Name: Month, Length: 158, dtype: int64

# %%
df.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month        int64
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156     True
# 157    False
# Length: 158, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3      9   28  2010    75       S

# %%
df[df.duplicated(keep=False)]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3      9   28  2010    75       S
# 156   14.0    191.0  14.3      9   28  2010    75       S

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (157, 8)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## **drop column**

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4      5    1  2010    67       S
# 1   36.0    118.0   8.0      5    2  2010    72       C
# 2   12.0    149.0  12.6      5    3  2010    74      PS
# 3   18.0    313.0  11.5      5    4  2010    62       S
# 4    NaN      NaN  14.3      5    5  2010    56       S

# %%
df.tail()
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 152   20.0    223.0  11.5      9   30  2010    68       S
# 153   41.0    190.0   7.4      5    1  2010    67       C
# 154   30.0    193.0   6.9      9   26  2010    70      PS
# 155    NaN    145.0  13.2      9   27  2010    77       S
# 157   18.0    131.0   8.0      9   29  2010    76       C

# %%
df['Year'].unique()
# Out:
# array([2010])

# %%
df.drop(columns=['Year'],inplace=True)

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0   41.0    190.0   7.4      5    1    67       S
# 1   36.0    118.0   8.0      5    2    72       C
# 2   12.0    149.0  12.6      5    3    74      PS
# 3   18.0    313.0  11.5      5    4    62       S
# 4    NaN      NaN  14.3      5    5    56       S

# %%
df.drop(columns=["Ozone","Month"])
# Out:
#      Solar.R  Wind  Day  Temp Weather
# 0      190.0   7.4    1    67       S
# 1      118.0   8.0    2    72       C
# 2      149.0  12.6    3    74      PS
# 3      313.0  11.5    4    62       S
# 4        NaN  14.3    5    56       S
# ..       ...   ...  ...   ...     ...
# 152    223.0  11.5   30    68       S
# 153    190.0   7.4    1    67       C
# 154    193.0   6.9   26    70      PS
# 155    145.0  13.2   27    77       S
# 157    131.0   8.0   29    76       C
#
# [157 rows x 5 columns]

# %%
df
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0     41.0    190.0   7.4      5    1    67       S
# 1     36.0    118.0   8.0      5    2    72       C
# 2     12.0    149.0  12.6      5    3    74      PS
# 3     18.0    313.0  11.5      5    4    62       S
# 4      NaN      NaN  14.3      5    5    56       S
# ..     ...      ...   ...    ...  ...   ...     ...
# 152   20.0    223.0  11.5      9   30    68       S
# 153   41.0    190.0   7.4      5    1    67       C
# 154   30.0    193.0   6.9      9   26    70      PS
# 155    NaN    145.0  13.2      9   27    77       S
# 157   18.0    131.0   8.0      9   29    76       C
#
# [157 rows x 7 columns]

# %%
#to drop record or a column
df.drop(index=[1])  #temporal change
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0     41.0    190.0   7.4      5    1    67       S
# 2     12.0    149.0  12.6      5    3    74      PS
# 3     18.0    313.0  11.5      5    4    62       S
# 4      NaN      NaN  14.3      5    5    56       S
# 5     28.0      NaN  14.9      5    6    66       C
# ..     ...      ...   ...    ...  ...   ...     ...
# 152   20.0    223.0  11.5      9   30    68       S
# 153   41.0    190.0   7.4      5    1    67       C
# 154   30.0    193.0   6.9      9   26    70      PS
# 155    NaN    145.0  13.2      9   27    77       S
# 157   18.0    131.0   8.0      9   29    76       C
#
# [156 rows x 7 columns]

# %%
df.drop(index=[3,4])
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0     41.0    190.0   7.4      5    1    67       S
# 1     36.0    118.0   8.0      5    2    72       C
# 2     12.0    149.0  12.6      5    3    74      PS
# 5     28.0      NaN  14.9      5    6    66       C
# 6     23.0    299.0   8.6      5    7    65      PS
# ..     ...      ...   ...    ...  ...   ...     ...
# 152   20.0    223.0  11.5      9   30    68       S
# 153   41.0    190.0   7.4      5    1    67       C
# 154   30.0    193.0   6.9      9   26    70      PS
# 155    NaN    145.0  13.2      9   27    77       S
# 157   18.0    131.0   8.0      9   29    76       C
#
# [155 rows x 7 columns]

# %% [markdown]
# ## **rename the column**

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0   41.0    190.0   7.4      5    1    67       S
# 1   36.0    118.0   8.0      5    2    72       C
# 2   12.0    149.0  12.6      5    3    74      PS
# 3   18.0    313.0  11.5      5    4    62       S
# 4    NaN      NaN  14.3      5    5    56       S

# %%
df
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0     41.0    190.0   7.4      5    1    67       S
# 1     36.0    118.0   8.0      5    2    72       C
# 2     12.0    149.0  12.6      5    3    74      PS
# 3     18.0    313.0  11.5      5    4    62       S
# 4      NaN      NaN  14.3      5    5    56       S
# ..     ...      ...   ...    ...  ...   ...     ...
# 152   20.0    223.0  11.5      9   30    68       S
# 153   41.0    190.0   7.4      5    1    67       C
# 154   30.0    193.0   6.9      9   26    70      PS
# 155    NaN    145.0  13.2      9   27    77       S
# 157   18.0    131.0   8.0      9   29    76       C
#
# [157 rows x 7 columns]

# %%
df.rename(columns={"Solar.R":"Solar","Temp":"Temperature"},inplace=True)  #in dictionary formate we used to relace a name of column

# %%
df
# Out:
#      Ozone  Solar  Wind  Month  Day  Temperature Weather
# 0     41.0  190.0   7.4      5    1           67       S
# 1     36.0  118.0   8.0      5    2           72       C
# 2     12.0  149.0  12.6      5    3           74      PS
# 3     18.0  313.0  11.5      5    4           62       S
# 4     31.0    NaN  14.3      5    5           56       S
# ..     ...    ...   ...    ...  ...          ...     ...
# 152   20.0  223.0  11.5      9   30           68       S
# 153   41.0  190.0   7.4      5    1           67       C
# 154   30.0  193.0   6.9      9   26           70      PS
# 155   31.0  145.0  13.2      9   27           77       S
# 157   18.0  131.0   8.0      9   29           76       C
#
# [157 rows x 7 columns]

# %% [markdown]
# ## **missing values**

# %%
0-5% missing values: drop row
6-45%              : replace the missing values
50%:drop column
# Out:
#   File "<ipython-input-40-754d022cc489>", line 1
#     0-5% missing values: drop row
#                  ^
# SyntaxError: invalid syntax

# %%
df.head()
# Out:
#    Ozone  Solar  Wind  Month  Day  Temperature Weather
# 0   41.0  190.0   7.4      5    1           67       S
# 1   36.0  118.0   8.0      5    2           72       C
# 2   12.0  149.0  12.6      5    3           74      PS
# 3   18.0  313.0  11.5      5    4           62       S
# 4   31.0    NaN  14.3      5    5           56       S

# %%
df.isna()   #isnull  ,true :missing values found
# Out:
#      Ozone  Solar   Wind  Month    Day  Temperature  Weather
# 0    False  False  False  False  False        False    False
# 1    False  False  False  False  False        False    False
# 2    False  False  False  False  False        False    False
# 3    False  False  False  False  False        False    False
# 4    False   True  False  False  False        False    False
# ..     ...    ...    ...    ...    ...          ...      ...
# 152  False  False  False  False  False        False    False
# 153  False  False  False  False  False        False    False
# 154  False  False  False  False  False        False    False
# 155  False  False  False  False  False        False    False
# 157  False  False  False  False  False        False    False
#
# [157 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# Ozone          0
# Solar          7
# Wind           0
# Month          0
# Day            0
# Temperature    0
# Weather        3
# dtype: int64

# %%
#visualize missing values
sns.heatmap(df.isna())  #where horizontal line are the missing values
# Out:
# <Axes: >

# %%
len(df)
# Out:
# 157

# %%
for i in df.isna().sum():  # to get percentage of missing values
  print((i/len(df))*100)  #ozone has a missing value is in the range 6 to 45%
  #solar,weather drop missing values
  #ozone and solar are numerical column if outliers are present in that column replace missing values
  #if no outliers in column replace missing value with mean
  #if categorical column replace missing value with mode
# Out:
# 24.203821656050955
# 4.45859872611465
# 0.0
# 0.0
# 0.0
# 0.0
# 1.910828025477707

# %%
df.hist()
plt.tight_layout()  #avoid overlapping of labels of graphs
#

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Ozone'}>,
#         <Axes: title={'center': 'Solar'}>],
#        [<Axes: title={'center': 'Wind'}>,
#         <Axes: title={'center': 'Month'}>],
#        [<Axes: title={'center': 'Day'}>,
#         <Axes: title={'center': 'Temperature'}>]], dtype=object)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['Wind'])
# Out:
# <Axes: xlabel='Wind'>

# %%
Ozone_median = df['Ozone'].median()
Ozone_median
# Out:
# 31.0

# %%
df['Ozone'].fillna(Ozone_median,inplace=True)

# %%
df.isna().sum()
# Out:
# Ozone          0
# Solar          7
# Wind           0
# Month          0
# Day            0
# Temperature    0
# Weather        3
# dtype: int64

# %%
df['Solar'].mean()
# Out:
# 185.36666666666667

# %%
df['Solar'].fillna(df['Solar'].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# Ozone          0
# Solar          0
# Wind           0
# Month          0
# Day            0
# Temperature    0
# Weather        3
# dtype: int64

# %%
df['Weather'].mode()
# Out:
# 0    S
# Name: Weather, dtype: object

# %%
df['Weather'].mode()[0]
# Out:
# 'S'

# %%
df['Weather'].fillna(df['Weather'].mode()[0],inplace=True)  #[0] for multimodal values select index 0

# %% [markdown]
# ## **outliers detection**

# %%
df.describe()
# Out:
#             Ozone       Solar        Wind       Month         Day  Temperature
# count  157.000000  157.000000  157.000000  157.000000  157.000000   157.000000
# mean    39.197452  185.366667    9.929936    7.019108   15.929936    77.745223
# std     28.781992   86.998999    3.505188    1.434338    8.974404     9.405334
# min      1.000000    7.000000    1.700000    5.000000    1.000000    56.000000
# 25%     21.000000  127.000000    7.400000    6.000000    8.000000    72.000000
# 50%     31.000000  193.000000    9.700000    7.000000   16.000000    79.000000
# 75%     45.000000  255.000000   11.500000    8.000000   24.000000    84.000000
# max    168.000000  334.000000   20.700000    9.000000   31.000000    97.000000

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Ozone'}>,
#         <Axes: title={'center': 'Solar'}>],
#        [<Axes: title={'center': 'Wind'}>,
#         <Axes: title={'center': 'Month'}>],
#        [<Axes: title={'center': 'Day'}>,
#         <Axes: title={'center': 'Temperature'}>]], dtype=object)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(x=df["Ozone"])
# Out:
# <Axes: xlabel='Ozone'>

# %% [markdown]
# ## **outliers treatement**
#  *capping:replace outliers values is called capping
#  *in capping all outliers values will be replaced by upper extreme

# %%
def userfunction():
  print("hello")
  print("function introduction")

# %%
userfunction()
# Out:
# hello
# function introduction

# %%
userfunction(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-a6bb4095381c> in <cell line: 1>()
# ----> 1 userfunction(10)
#
# TypeError: userfunction() takes 0 positional arguments but 1 was given

# %%
len()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-adf3103c7c3e> in <cell line: 1>()
# ----> 1 len()
#
# TypeError: len() takes exactly one argument (0 given)

# %%
len(df)
# Out:
# 157

# %%
def add(num1,num2):
  print(num1+num2)

# %%
add(10,20)
# Out:
# 30

# %%
add()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-d5d29de3ed94> in <cell line: 1>()
# ----> 1 add()
#
# TypeError: add() missing 2 required positional arguments: 'num1' and 'num2'

# %%
def arithmatic(num1,num2):
  print("add",num1+num2)
  print("sub",num1-num2)
  print("mul",num1*num2)
  print("div",num1/num2)
arithmatic(40,4)
# Out:
# add 44
# sub 36
# mul 160
# div 10.0

# %%
"spoorthi"+" "+"prasad"
# Out:
# 'spoorthi prasad'

# %%
def addtext(text1,text2):
  text3=text1+' '+text2
 # return text3
  print(text3)
addtext("string","concatination")
# Out:
# string concatination

# %%
df['Ozone'].quantile(0.25)  #lower quantile at 25%
# Out:
# 21.0

# %%
df['Ozone'].quantile(0.75)    #upper quantile at 75%
# Out:
# 45.0

# %%
#outlier detection :user defined function to calculate upper and lower extreme
def outlier_detection(data,colname):
  q1=data[colname].quantile(0.25)
  q2=data[colname].quantile(0.75)
  iqr=q2-q1
  lower_extreme = q1-(1.5*iqr)
  upper_extreme = q2+(1.5*iqr)
  return lower_extreme , upper_extreme, q2,q1

# %%
outlier_detection(df,"Ozone")  #more than all value are considered as outliers
# Out:
# (-15.0, 81.0, 45.0, 21.0)

# %%
outlier_detection(df,"Wind")
# Out:
# (1.2500000000000009, 17.65, 11.5, 7.4)

# %%
import plotly .express as pe

# %%
pe.scatter(x=df["Ozone"],y=df["Temperature"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#extract all element in ozone with is greater than upper extreme
df[df['Ozone']>81.0]
# Out:
#      Ozone  Solar  Wind  Month  Day  Temperature Weather
# 29   115.0  223.0   5.7      5   30           79       C
# 61   135.0  269.0   4.1      7    1           84       S
# 68    97.0  267.0   6.3      7    8           92      PS
# 69    97.0  272.0   5.7      7    9           92       C
# 70    85.0  175.0   7.4      7   10           89      PS
# 85   108.0  223.0   8.0      7   25           85      PS
# 88    82.0  213.0   7.4      7   28           88       S
# 98   122.0  255.0   4.0      8    7           89       C
# 99    89.0  229.0  10.3      8    8           90      PS
# 100  110.0  207.0   8.0      8    9           90       C
# 116  168.0  238.0   3.4      8   25           81      PS
# 120  118.0  225.0   2.3      8   29           94       S
# 121   84.0  237.0   6.3      8   30           96       S
# 122   85.0  188.0   6.3      8   31           94       C
# 123   96.0  167.0   6.9      9    1           91       C
# ...

# %%
df[df['Ozone']>81.0].shape[0]  #length of rows
# Out:
# 16

# %%
df[df['Ozone']>81.0].shape[1]  #length of columns
# Out:
# 7

# %%
#the 16 outliers values of ozone column should be replaced by upper extreme
df.loc[df['Ozone']>81.0,"Ozone"]
# Out:
# 29     115.0
# 61     135.0
# 68      97.0
# 69      97.0
# 70      85.0
# 85     108.0
# 88      82.0
# 98     122.0
# 99      89.0
# 100    110.0
# 116    168.0
# 120    118.0
# 121     84.0
# 122     85.0
# 123     96.0
# 126     91.0
# Name: Ozone, dtype: float64

# %%
#capping outliers in ozonE column
df.loc[df['Ozone']>81.0,"Ozone"]=81.0

# %%
df.loc[df['Ozone']>81.0]  #no value are displayed as all outliers are replaced by 81.0
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar, Wind, Month, Day, Temperature, Weather]
# Index: []

# %%
df[df['Ozone']==81.0]
# Out:
#      Ozone  Solar  Wind  Month  Day  Temperature Weather
# 29    81.0  223.0   5.7      5   30           79       C
# 61    81.0  269.0   4.1      7    1           84       S
# 68    81.0  267.0   6.3      7    8           92      PS
# 69    81.0  272.0   5.7      7    9           92       C
# 70    81.0  175.0   7.4      7   10           89      PS
# 85    81.0  223.0   8.0      7   25           85      PS
# 88    81.0  213.0   7.4      7   28           88       S
# 98    81.0  255.0   4.0      8    7           89       C
# 99    81.0  229.0  10.3      8    8           90      PS
# 100   81.0  207.0   8.0      8    9           90       C
# 116   81.0  238.0   3.4      8   25           81      PS
# 120   81.0  225.0   2.3      8   29           94       S
# 121   81.0  237.0   6.3      8   30           96       S
# 122   81.0  188.0   6.3      8   31           94       C
# 123   81.0  167.0   6.9      9    1           91       C
# ...

# %%
#do it for wind column also

# %%
df[df['Wind']==17.65]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar, Wind, Month, Day, Temperature, Weather]
# Index: []

# %%
sns.boxplot(x=df["Wind"])
# Out:
# <Axes: xlabel='Wind'>

# %%
df[df['Wind']>17.65]
# Out:
#     Ozone  Solar  Wind  Month  Day  Temperature Weather
# 8     8.0   19.0  20.1      5    9           61      PS
# 17    6.0   78.0  18.4      5   18           57       C
# 47   37.0  284.0  20.7      6   17           72       C

# %%
df.loc[df['Wind']>17.65,"Wind"]==17.65
# Out:
# 8     False
# 17    False
# 47    False
# Name: Wind, dtype: bool

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (157, 7)

# %% [markdown]
# ## **scatter plot and correction**

# %%
df.head()
# Out:
#    Ozone       Solar  Wind  Month  Day  Temperature Weather
# 0   41.0  190.000000   7.4      5    1           67       S
# 1   36.0  118.000000   8.0      5    2           72       C
# 2   12.0  149.000000  12.6      5    3           74      PS
# 3   18.0  313.000000  11.5      5    4           62       S
# 4   31.0  185.366667  14.3      5    5           56       S

# %%
sns.pairplot(df)  #relationship between all numerical column
#check graph of month(x axis) v/stemperature
#we got 5 vertical lines in it because datatype of month is discreate numerical value it has only 5 unique discreate numerical value
#it show no relationship between month and temperature

# %%
df['Weather'].value_counts()
# Out:
# Weather
# S     61
# C     49
# PS    47
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)
#ozone vs ozone corr=1.0 so ignore diagonal values
#ozone vs temperature corr=0.66 so + moderate correlation
#for large number of column go for heatmap visualization
# Out:
#                 Ozone     Solar      Wind     Month       Day  Temperature
# Ozone        1.000000  0.317926 -0.514470  0.183089 -0.042835     0.662773
# Solar        0.317926  1.000000 -0.055874 -0.080237 -0.151007     0.260677
# Wind        -0.514470 -0.055874  1.000000 -0.170328  0.029900    -0.441228
# Month        0.183089 -0.080237 -0.170328  1.000000  0.041438     0.408060
# Day         -0.042835 -0.151007  0.029900  0.041438  1.000000    -0.122787
# Temperature  0.662773  0.260677 -0.441228  0.408060 -0.122787     1.000000

# %%
df.corr(numeric_only=True)
#diagonal value is always same(i.e =1)
# Out:
#                 Ozone     Solar      Wind     Month       Day  Temperature
# Ozone        1.000000  0.317926 -0.514470  0.183089 -0.042835     0.662773
# Solar        0.317926  1.000000 -0.055874 -0.080237 -0.151007     0.260677
# Wind        -0.514470 -0.055874  1.000000 -0.170328  0.029900    -0.441228
# Month        0.183089 -0.080237 -0.170328  1.000000  0.041438     0.408060
# Day         -0.042835 -0.151007  0.029900  0.041438  1.000000    -0.122787
# Temperature  0.662773  0.260677 -0.441228  0.408060 -0.122787     1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
#-1 to 1 graph
#light colour will be strong 1
#dark will be nagative
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="viridis")
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="rainbow")
# Out:
# <Axes: >

# %% [markdown]
# ## **Transformation**
#  convert text data to numerial before model building

# %%
df.head()
# Out:
#    Ozone       Solar  Wind  Month  Day  Temperature Weather
# 0   41.0  190.000000   7.4      5    1           67       S
# 1   36.0  118.000000   8.0      5    2           72       C
# 2   12.0  149.000000  12.6      5    3           74      PS
# 3   18.0  313.000000  11.5      5    4           62       S
# 4   31.0  185.366667  14.3      5    5           56       S

# %%
#encoding using pandas dummy function
df=pd.get_dummies(data=df,columns =["Weather"])  #data word should be must

# %%
df
# Out:
#      Ozone       Solar  Wind  Month  Day  Temperature  Weather_C  Weather_PS  \
# 0     41.0  190.000000   7.4      5    1           67      False       False
# 1     36.0  118.000000   8.0      5    2           72       True       False
# 2     12.0  149.000000  12.6      5    3           74      False        True
# 3     18.0  313.000000  11.5      5    4           62      False       False
# 4     31.0  185.366667  14.3      5    5           56      False       False
# ..     ...         ...   ...    ...  ...          ...        ...         ...
# 152   20.0  223.000000  11.5      9   30           68      False       False
# 153   41.0  190.000000   7.4      5    1           67       True       False
# 154   30.0  193.000000   6.9      9   26           70      False        True
# 155   31.0  145.000000  13.2      9   27           77      False       False
# 157   18.0  131.000000   8.0      9   29           76       True       False
#
#      Weather_S
# 0         True
# ...

# %% [markdown]
# ## **scalling the data**
#
#
# 1. bring down all column to same scale
# 2. normalization :scale value within the range 0 to 1
# 3. standardization:uses z score for scaling scale values in such a way that the mean=0 and std =1

# %%
from sklearn.preprocessing import StandardScaler ,MinMaxScaler

# %%
sc= StandardScaler()   #create an instance

# %%
sc.fit_transform(df) # all value transformed between 3 to -3
# Out:
# array([[ 0.19019358,  0.05342774, -0.72407878, ..., -0.67357531,
#         -0.65366102,  1.2545001 ],
#        [-0.03297826, -0.7768163 , -0.55235617, ...,  1.48461498,
#         -0.65366102, -0.79713027],
#        [-1.10420306, -0.41935011,  0.76418385, ..., -0.67357531,
#          1.52984494, -0.79713027],
#        ...,
#        [-0.30078446,  0.08802124, -0.86718096, ..., -0.67357531,
#          1.52984494, -0.79713027],
#        [-0.25615009, -0.46547478,  0.93590646, ..., -0.67357531,
#         -0.65366102,  1.2545001 ],
#        [-0.83639686, -0.62691113, -0.55235617, ...,  1.48461498,
#         -0.65366102, -0.79713027]])

# %%
#sc.fit():all calculation will be done  here
#sc.transform():orginal value replace by transform() value
#sc.fit_transform():does both the above task

# %%
pd.DataFrame(sc.fit_transform(df))  #convert matrix form into a data set format
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.190194  0.053428 -0.724079 -1.412198 -1.668937 -1.146116 -0.673575
# 1   -0.032978 -0.776816 -0.552356 -1.412198 -1.557152 -0.612802  1.484615
# 2   -1.104203 -0.419350  0.764184 -1.412198 -1.445367 -0.399476 -0.673575
# 3   -0.836397  1.471761  0.449359 -1.412198 -1.333583 -1.679431 -0.673575
# 4   -0.256150  0.000000  1.250731 -1.412198 -1.221798 -2.319408 -0.673575
# ..        ...       ...       ...       ...       ...       ...       ...
# 152 -0.747128  0.433956  0.449359  1.385469  1.572816 -1.039454 -0.673575
# 153  0.190194  0.053428 -0.724079 -1.412198 -1.668937 -1.146116  1.484615
# 154 -0.300784  0.088021 -0.867181  1.385469  1.125678 -0.826128 -0.673575
# 155 -0.256150 -0.465475  0.935906  1.385469  1.237462 -0.079488 -0.673575
# 156 -0.836397 -0.626911 -0.552356  1.385469  1.461032 -0.186150  1.484615
#
#             7        8
# 0   -0.653661  1.25450
# 1   -0.653661 -0.79713
# ...

# %%
df.columns  #gives an column namaes
# Out:
# Index(['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Temperature', 'Weather_C',
#        'Weather_PS', 'Weather_S'],
#       dtype='object')

# %%
#convert scaled array into dataframe .for this standardized data mean=0 and std=1
scaled_data=pd.DataFrame(sc.fit_transform(df),columns=df.columns)  #to obtain exact column name instead of 0,1,2.....

# %%
scaled_data
# Out:
#         Ozone     Solar      Wind     Month       Day  Temperature  Weather_C  \
# 0    0.190194  0.053428 -0.724079 -1.412198 -1.668937    -1.146116  -0.673575
# 1   -0.032978 -0.776816 -0.552356 -1.412198 -1.557152    -0.612802   1.484615
# 2   -1.104203 -0.419350  0.764184 -1.412198 -1.445367    -0.399476  -0.673575
# 3   -0.836397  1.471761  0.449359 -1.412198 -1.333583    -1.679431  -0.673575
# 4   -0.256150  0.000000  1.250731 -1.412198 -1.221798    -2.319408  -0.673575
# ..        ...       ...       ...       ...       ...          ...        ...
# 152 -0.747128  0.433956  0.449359  1.385469  1.572816    -1.039454  -0.673575
# 153  0.190194  0.053428 -0.724079 -1.412198 -1.668937    -1.146116   1.484615
# 154 -0.300784  0.088021 -0.867181  1.385469  1.125678    -0.826128  -0.673575
# 155 -0.256150 -0.465475  0.935906  1.385469  1.237462    -0.079488  -0.673575
# 156 -0.836397 -0.626911 -0.552356  1.385469  1.461032    -0.186150   1.484615
#
#      Weather_PS  Weather_S
# ...

# %%
scaled_data.describe()  #mean always 0 and std = 1
# Out:
#               Ozone         Solar          Wind         Month           Day  \
# count  1.570000e+02  1.570000e+02  1.570000e+02  1.570000e+02  1.570000e+02
# mean  -3.394312e-17 -9.051500e-17 -4.525750e-17  1.810300e-16 -2.262875e-17
# std    1.003200e+00  1.003200e+00  1.003200e+00  1.003200e+00  1.003200e+00
# min   -1.595181e+00 -2.056776e+00 -2.355444e+00 -1.412198e+00 -1.668937e+00
# 25%   -7.024938e-01 -6.730358e-01 -7.240788e-01 -7.127815e-01 -8.864446e-01
# 50%   -2.561501e-01  8.802124e-02 -6.580877e-02 -1.336465e-02  7.832041e-03
# 75%    3.687310e-01  8.029536e-01  4.493591e-01  6.860522e-01  9.021087e-01
# max    1.975568e+00  1.713916e+00  3.082439e+00  1.385469e+00  1.684601e+00
#
#         Temperature     Weather_C    Weather_PS     Weather_S
# count  1.570000e+02  1.570000e+02  1.570000e+02  1.570000e+02
# mean   2.036587e-16  4.242891e-17 -8.485781e-18 -7.849347e-17
# std    1.003200e+00  1.003200e+00  1.003200e+00  1.003200e+00
# ...

# %% [markdown]
# MinMaxScaler()

# %%
mn=MinMaxScaler()

# %%
df.columns
# Out:
# Index(['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Temperature', 'Weather_C',
#        'Weather_PS', 'Weather_S'],
#       dtype='object')

# %%
minmax_scaled.describe()
# Out:
#             Ozone       Solar        Wind       Month         Day  \
# count  157.000000  157.000000  157.000000  157.000000  157.000000
# mean     0.446736    0.545464    0.433155    0.504777    0.497665
# std      0.280949    0.266052    0.184484    0.358584    0.299147
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.250000    0.366972    0.300000    0.250000    0.233333
# 50%      0.375000    0.568807    0.421053    0.500000    0.500000
# 75%      0.550000    0.758410    0.515789    0.750000    0.766667
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        Temperature   Weather_C  Weather_PS   Weather_S
# count   157.000000  157.000000  157.000000  157.000000
# mean      0.530371    0.312102    0.299363    0.388535
# std       0.229398    0.464834    0.459445    0.488977
# min       0.000000    0.000000    0.000000    0.000000
# 25%       0.390244    0.000000    0.000000    0.000000
# ...

# %%
minmax_scaled=pd.DataFrame(mn.fit_transform(df),columns=df.columns)
minmax_scaled
# Out:
#       Ozone     Solar      Wind  Month       Day  Temperature  Weather_C  \
# 0    0.5000  0.559633  0.300000    0.0  0.000000     0.268293        0.0
# 1    0.4375  0.339450  0.331579    0.0  0.033333     0.390244        1.0
# 2    0.1375  0.434251  0.573684    0.0  0.066667     0.439024        0.0
# 3    0.2125  0.935780  0.515789    0.0  0.100000     0.146341        0.0
# 4    0.3750  0.545464  0.663158    0.0  0.133333     0.000000        0.0
# ..      ...       ...       ...    ...       ...          ...        ...
# 152  0.2375  0.660550  0.515789    1.0  0.966667     0.292683        0.0
# 153  0.5000  0.559633  0.300000    0.0  0.000000     0.268293        1.0
# 154  0.3625  0.568807  0.273684    1.0  0.833333     0.341463        0.0
# 155  0.3750  0.422018  0.605263    1.0  0.866667     0.512195        0.0
# 156  0.2125  0.379205  0.331579    1.0  0.933333     0.487805        1.0
#
#      Weather_PS  Weather_S
# 0           0.0        1.0
# 1           0.0        0.0
# ...
